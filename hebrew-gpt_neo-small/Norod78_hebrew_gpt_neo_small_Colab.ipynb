# %% [markdown]
# <a href="https://colab.research.google.com/github/Norod/hebrew-gpt_neo/blob/main/hebrew-gpt_neo-small/Norod78_hebrew_gpt_neo_small_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tokenizers==0.10.2 transformers==4.6.0
# Out:
# Collecting tokenizers==0.10.2
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 15.2MB/s
# Collecting transformers==4.6.0
#   Downloading https://files.pythonhosted.org/packages/b0/9e/5b80becd952d5f7250eaf8fc64b957077b12ccfe73e9c03d37146ab29712/transformers-4.6.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 42.1MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 38.3MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (4.0.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (20.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (2019.12.20)
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.0) (1.19.5)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.0) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.6.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.6.0) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.6.0) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.0) (2.10)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.2 transformers-4.6.0

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
  
tokenizer = AutoTokenizer.from_pretrained("Norod78/hebrew-gpt_neo-small")
model = AutoModelForCausalLM.from_pretrained("Norod78/hebrew-gpt_neo-small", pad_token_id=tokenizer.eos_token_id)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=992.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1460069.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1017862.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=72.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=90.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=216.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=551185927.0, style=ProgressStyle(descri…

# %%
prompt_text = "אני אוהב שוקולד ועוגות"
max_len = 512
sample_output_num = 3
seed = 1000

# %%
import numpy as np
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = 0 if torch.cuda.is_available()==False else torch.cuda.device_count()

print(f"device: {device}, n_gpu: {n_gpu}")

np.random.seed(seed)
torch.manual_seed(seed)
if n_gpu > 0:
    torch.cuda.manual_seed_all(seed)

model.to(device)

encoded_prompt = tokenizer.encode(
    prompt_text, add_special_tokens=False, return_tensors="pt")

encoded_prompt = encoded_prompt.to(device)

if encoded_prompt.size()[-1] == 0:
        input_ids = None
else:
        input_ids = encoded_prompt

print("input_ids = " + str(input_ids))

if input_ids != None:
  max_len += len(encoded_prompt[0])
  if max_len > 2048:
    max_len = 2048

print("Updated max_len = " + str(max_len))
# Out:
# device: cuda, n_gpu: 1
# input_ids = tensor([[ 2202, 22283, 10984,   631,  5679]], device='cuda:0')
# Updated max_len = 517

# %%
stop_token = "<|endoftext|>"
new_lines = "\n\n\n"

sample_outputs = model.generate(
    input_ids,
    do_sample=True, 
    max_length=max_len, 
    top_k=50, 
    top_p=0.95, 
    num_return_sequences=sample_output_num
)

print(100 * '-' + "\n\t\tOutput\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):

  text = tokenizer.decode(sample_output, skip_special_tokens=True)
  
  # Remove all text after the stop token
  text = text[: text.find(stop_token) if stop_token else None]

  # Remove all text after 3 newlines
  text = text[: text.find(new_lines) if new_lines else None]

  print("\n{}: {}".format(i, text))
  print("\n" + 100 * '-')
# Out:
# ----------------------------------------------------------------------------------------------------
# 		Output
# ----------------------------------------------------------------------------------------------------
#
# 0: אני אוהב שוקולד ועוגות בכלל. אני גם מאוד אוהבת להכין עוגות.
# התנור שלי הוא טורבו. יש לי תנור רגיל עם טורבו. אני משתמשת בזה הרבה. לפני כמה חודשים, כשהתנור שלי התקשה, עשיתי על הגז חימום והפעלתי גז טורבו, עד שהגעתי לטמפרטורה של 35 מעלות, והחימום לא השפיע.
# אני משתמשת בזה גם הרבה, אבל הכי הרבה, כי בכל זאת יש לי תנור, אז הייתי בטוחה שאני מכפילה את זה, כי פשוט לא הייתי בטוחה אם יתקנו לי תנור כמו שצריך. זה לא עבד.
# כשאני יושבת להכין עוגות שמרים, אני מוצאת את עצמי במטבח, יושבת שעה-שעתיים, מברכת על העוגה הבאה, ואז כשמתחילים להכין עוגת שמרים, מתמלא בי כל העונג. ואז יש לי עוגה שאני לא יכולה לאפות אותה, אז אני הולכת למטבח, מביטה באמה שלי ואומרת לה:'תודה שאת כל כך אופה. את הרי יודעת שהאור הלבן הכי יפה. את בטח אוהבת אותי. אז בואי נכין עוגה!'. היא מתרגזת ושואלת אותי:'אז מה, אמא, את מכבסת?'אני אומרת לה:'למה את לא מכבסת?'אני פותחת את הסיר ומקלפת את העוגה והיא עושה את זה יפה. היא לא מכבסת ואני מכבסת את כל העוגה. ואז אני רואה את העוגה. אני מכינה לה קרקרים מעוכים, אני מכבסת גם את שאר התנור. אמא, אמא, את אוהבת את כל זה?'.
# סבתא אומרת:'תני לי להגיד לך, תודי לי, אני אוהבת את כל זה, את כל הקישקע'. אבא אומר:'גם אני אוהב, אבל רק אחרי שאני מכניסה את העוגה לתנור', כי אני ממש אוהבת, אז אני הולכת למטבח, מדליקה את התנור ומקלפת את הקישקע, והוא עולה למעלה, אז אמא שלי אומרת:'תודה רבה, תודי לי, אני אוהבת כל זה, אבל רק אחרי שאני מכניסה את העוגה לתנור'אני רואה שעשיתי את זה יפה. אז אמא אומרת:'תודה רבה'. אני מכינה לה קרקרים מעוכים, וגם אותה אני מכניסה לתנור, אבל היא כבר אכלה את הקישקע, ובגלל שזה גם היה לפני, היא לא יכולה.
# אני אוכלת כל מה שזז בבית, לא כל דבר שתאכלי זה טוב. אז אני הולכת למטבח, ואני אוכלת מכל הלב. אני רואה שעש
#
# ----------------------------------------------------------------------------------------------------
#
# 1: אני אוהב שוקולד ועוגות גבינה..."אני אוהבת שוקולד, עוגת גבינה של ממש, אבל לא הייתי מכינה אותה לבד... מה אני אגיד לכם, לא הייתי מכינה אותה לבד...
# יש אנשים שפשוט"מחכים שיתחילו לפצוח בסתם שנה, יש כאלה שדורשים שנה טובה ומתוקה (אבל לא רק...), ויש כאלה שחוששים שנתחדל. כך או כך, אני מזמינה אתכם להצטרף אלינו למסעדה שאמורה להיות מלאה בכל טוב, בתוצרת נפלאה ובטעמים, ולשמוע אתכם כל הדרך הביתה...
#
# ----------------------------------------------------------------------------------------------------
#
# 2: אני אוהב שוקולד ועוגות קטנות".
# אם יש מישהו שלמד את סוד ההנאה של עוגות יקרות יותר, אלו הם הקונדיטורים. הם מתמחים בהכנה של עוגות מיוחדות, טעימות ואווריריות, העשויות מתמציות של שוקולד מריר, קפה ושמן קנולה. יש גם עוגות גדולות וטעימות, שעשויות ממיצוי של שוקולד או עוגיות. אך בכל הנוגע להכנה של עוגות יקרות יותר, יש גם עוגות גדולות ועוגות יקרות יותר.
# יש הרבה סוגים של עוגות יקרות, אבל אם מדובר על עוגת שוקולד, העוגה הזו היא עוגת הבית של הקונדיטורים. מדובר על עוגות של ממש, אך יש גם עוגות שוקולד עשירות, אשר מתחככות בקינמון וחמות בצורה יוצאת דופן. כמו במקרה הזה, אתם יכולים להתפרע עם עוגות יקרות יותר או להכין לבד עוגת שוקולד טעימה ויחידה. אז איך לאזן בין העוגה הפשוטה, המתוקה והתחתונה?
#
# ----------------------------------------------------------------------------------------------------

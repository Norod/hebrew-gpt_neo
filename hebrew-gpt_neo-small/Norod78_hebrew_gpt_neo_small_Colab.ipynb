# %% [markdown]
# <a href="https://colab.research.google.com/github/Norod/hebrew-gpt_neo/blob/main/hebrew-gpt_neo-small/Norod78_hebrew_gpt_neo_small_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tokenizers==0.10.2 transformers==4.5.1
# Out:
# Collecting tokenizers==0.10.2
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 7.2MB/s
# Collecting transformers==4.5.1
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 37.7MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (3.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (3.0.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 37.0MB/s
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.5.1) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.5.1) (3.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1) (2020.12.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.5.1) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 tokenizers-0.10.2 transformers-4.5.1

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
  
tokenizer = AutoTokenizer.from_pretrained("Norod78/hebrew-gpt_neo-small")
model = AutoModelForCausalLM.from_pretrained("Norod78/hebrew-gpt_neo-small", pad_token_id=tokenizer.eos_token_id)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=992.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1460069.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1017862.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=90.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=216.0, style=ProgressStyle(description_…
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=551187055.0, style=ProgressStyle(descri…

# %%
prompt_text = "אני אוהב שוקולד ועוגות"
max_len = 512
sample_output_num = 3
seed = 1000

# %%
import numpy as np
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = 0 if torch.cuda.is_available()==False else torch.cuda.device_count()

print(f"device: {device}, n_gpu: {n_gpu}")

np.random.seed(seed)
torch.manual_seed(seed)
if n_gpu > 0:
    torch.cuda.manual_seed_all(seed)

model.to(device)

encoded_prompt = tokenizer.encode(
    prompt_text, add_special_tokens=False, return_tensors="pt")

encoded_prompt = encoded_prompt.to(device)

if encoded_prompt.size()[-1] == 0:
        input_ids = None
else:
        input_ids = encoded_prompt

print("input_ids = " + str(input_ids))

if input_ids != None:
  max_len += len(encoded_prompt[0])
  if max_len > 2048:
    max_len = 2048

print("Updated max_len = " + str(max_len))
# Out:
# device: cuda, n_gpu: 1
# input_ids = tensor([[ 2202, 22283, 10984,   631,  5679]], device='cuda:0')
# Updated max_len = 517

# %%
sample_outputs = model.generate(
    input_ids,
    do_sample=True, 
    max_length=max_len, 
    top_k=50, 
    top_p=0.95, 
    num_return_sequences=sample_output_num
)

print(100 * '-' + "\nOutput:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
  print("\n{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
  print("\n" + 100 * '-')
# Out:
# ----------------------------------------------------------------------------------------------------
# Output:
# ----------------------------------------------------------------------------------------------------
#
# 0: אני אוהב שוקולד ועוגות בכלל. אני משתמש בגלידת וניל, חלב שקדים, פירות, קרם בננה, פירות יער ועוד הרבה... אז איך זה בכלל קיים פה בארץ?
# אומרים, שבשביל השוקולד צריכים שוקולד ולא סוכר, סוכר. סוכר הוא חומר גלם משובח מאוד, מה שיוצר סוכר לבן ומבריק כמו שיש לנו בשוקולד. הסוכר הוא חומר גלם, הוא מרכיב מתוק, אבל לא סוכר. אנחנו מכירים אותו כבר המון שנים אבל רק עם עוגיות הוא מתפתח והופך לבלילה מתוקה ועדינה.
# אז אם אתה חובב שוקולד מושבע וחובב מתוק, תסתכל על העוגיות הבאות: עוגת קצפת, עוגיות מקרון, עוגייה ביתית ועוד עוגיות שוקולד צ'יפס.
# עוגות ביתיות הן אחת העוגות האלה, כי הן מתוקות ומתוקה. העוגות הללו הן מסוג העוגות שהילדים לא צריכים, אלא מעדיפים עוגות ביתיות, בריאות וטעימות. לא?
# האמת – יש את כל סוגי העוגות. העוגות האלה פשוט לא מסוכרות. הן בטח לא מכילות גלוטן. הן לא מבושלות, אפויות, קפואות או עם שוקולד לבן... אם רוצים פשוט להכין את העוגות. כי הן מאוד אוהבות להיות קרות מבפנים.
# אז מה אפשר להכין לעוגות ביתיות? הן לא סתם. הם פשוט יכללו את כל העוגות שאומרות לך עד כמה טעמן מתוק ושמח. אז גם פה.
#
# במסגרת תהליך הפיתוח והפיתוח של האתר ניתן להוריד מאתר e-go עדכוני תוכן שונים כגון הודעות, וידאו, בלוג.
# עם זאת, במידה ואינכם מעוניינים להחשף לתוכן מסויים אנא אל תפרסמו אותו באתר ego. זה יחסוך לכם זמן וכסף.
# עם זאת, במידה ותבחרו לפרסם מידע באתר, האתר יראה לכם תוכן של גולש אשר ביצע פעולה כלשהי. כמו כן, אתם מוזמנים לבקר בעמוד הראשי.
# לאחר קבלת עדכונים על כל השינויים אשר מופיעים באתר, על האתר לפעול בהתאם לחוקים ולתנאים הרלבנטיים הבאים:
#
#
# לאחר שהתברר כי עד המדינה שמואל דכנר לא יאשר את הגשת דוחותיו, הודיע בית המשפט המחוזי בחיפה: האם הוא סבור, כפי שטען עד המדינה, כי החקירה בעניין זדורוב תישאר על כנה?
# במסגרת בקשת המשטרה לחקור את שמואל דכנר, עד המדינה שמואל דכנר, טען כי החוקרים, שזומנו לחקירה, העבירו לו חומרים נוספים.
# לדברי הפרקליטות, החומרים בתיק זדורוב היו נתונים לפרקליט, והם כללו חומרים אחרים, כך שבפועל הוא לא ידע שהראיות שיוצגו לו הם
#
# ----------------------------------------------------------------------------------------------------
#
# 1: אני אוהב שוקולד ועוגות! תודה רבה על מתכון נפלא!
# מהיום הראשון של ההכנות לתנור ראיתי מתכונים מתוקים שונים וטעימים, לא זוכרת מה בדיוק היה לי... אז איך אני עושה את זה? מצאתי מתכון מעולה, פשוט וקולע מאוד, טעים, פשוט ומתאים... מתכון פשוט להכנה מהירה של העוגה.
# אפשר להכין עם בצק פריך או בצק פריך? לא צריך לחכות לתבנית שתשים לב, פשוט שמים במקרר את מה שבאמת חשוב, שמים קמח, שמים סוכר, מוסיפים מים, טורפים מעט את הביצה ולשים עד שמסיימים את הבצק.
# אני מעדיפה בצק פריך, כמו בצק פריך שלוקח קצת יותר זמן. זה עובד כל-כך טוב עם כל מנה בנפרד, עם כל ביס בנפרד.
# אני ממש אוהבת את כל מה שאני מכינה. אני אוהבת את המתכונים שלך, את הנימוחות, את הקיצביים, את הטעם, את המתיקות, את הקלילות, את הריח. המתכונים שלך כיפיים, פשוטים, מלמדים, פשוטים וטעימים.
# את עושה עבודה נפלאה – פשוט תעשי את העוגה עם כל מיני שינויים, את יכולה לשים לב מה קורה עכשיו?
# הכנת הקלתית: מכניסים את הבצק לכפית עד שהוא מוכן, מהדקים היטב. מכסים את העוגה ומניחים בצד.
# מתכון פשוט של בצק פריך. יש להקפיד שהשכבה הראשונה לא תהייה רכה יותר. היא לא תיראה לי דקה. חשוב שהשכבה השניה לא תראה דקה. כך היא לא תיראה דקה, כי לא רואים שום צורה של עיגול (קארדסטוק).
# כשבוחרים קרם אפוי, צריך להוסיף את הקמח. הוא יקר, הוא נוזלי, הוא לא ממש בריא. אבל ברגע שהוא נטמע בתוכו, אפשר לעבוד איתו, לעבוד איתו, פשוט להעמיס על המילוי.
# מחממים תנור ל-250 מעלות – מניחים בסיר גדול מעל להבה בינונית (אפשר גם ב-5-6 מעלות) את הסוכר ומערבבים במהירות נמוכה.
# בקערה בינונית, מערבבים את החמאה והסוכר החום עם הסוכר. מוסיפים את הקמח, מערבבים במטרף, מתחדשים במהירות גבוהה, מוסיפים את הביצים אחת אחת עד שהבלילה משנה את המרקם שלה. מוסיפים את הדבש ומערבבים עד שמתגבש קצף. מסירים מהאש ומקררים במקרר.
# מעבירים את הקרם לשקית זילוף במרכז כל צנצנת ומצפים אותה בשמן זית או שמן קנולה.
# בידיים: מערבבים את כל החומרים במחבת (מערב
#
# ----------------------------------------------------------------------------------------------------
#
# 2: אני אוהב שוקולד ועוגות.
# אתן יכולות לקפוץ לביקור במטבח ולהמליץ על קינוח מתוק, כי כל קינוח הוא חגיגה אמיתית
# אם חשבתם שהמלצת היום היא לחגוג עם המשפחה או עם החברים או עם המשפחה הקרובה, אז עכשיו זה הזמן לתת
# שוקולד הוא טעים וטעים לכל ארוחה, כל אחת יכולה להכין איתו קינוח או משהו. אך בכל מקרה יש
# עוגת שוקולד תמיד מעידה על הטעם של האנשים, את הקונדיטור או את כל המשפחה,
# המנות האלה מכילות לא מעט מרכיבים והן קלות להכנה: סוכר, קינמון ואגוזים. לכן, כשמקפיאים,
# אין לכם מושג מה קרה עד עכשיו כשנכנסים לטעם האישי, אז החלטנו להגיש לכם מתכון מיוחד לטעמים
# כל פעם שאנחנו מגיעים לבית או למטבח, צריך להחליט איזה קינוח לפנק אותו עם קינוחים, ואז כמובן
# לקינוח הזה מגיעים אנשים מכל הסוגים, אך כולם מדברים על זה שזה טעים. אז אחרי כמה
# פירות טריים ושקדים קלויים, אנחנו צריכים תמיד לבחור קינוח אחד או שניים, בהתאם לטעם. אז איך
# איך אפשר להגיש את הקינוחים, אבל תמיד נזהרים לא להגיע לטעמים עד כדי כך מוגזמים, רק כי לא
# עוגת השוקולד היא אחת הטובות שיצא לי להכין, והיא עושה בדיוק את אותה עבודה. אז איך
# יודעים להכין את העוגה הזו, אבל יש כמה וכמה שלבים, חלקם מתחילים בכמה דקות, וחלקם
# משלבים את הקינוח הבסיסי. יש כל מיני דברים, אז בחרתי שלושה, כמו: מילוי עוגת
# שוקולד – כמו שאמרתי קודם, הכל תלוי בכמות המילוי. אני מעדיף כמות נמוכה,
# מתכון לעוגה שלוקח כחצי שעה עד שמגיעים לתוצאה מושלמת. חשוב מאוד להשתמש בחצי
# שלב, כדי שכל העוגה תהיה שלמה. את זה אני אוהב להשתמש בכל מיני תמרים, רק צריך
# לגוון את העוגה. אז מה כדאי לאכול: עוגה טעימה, עם שילוב נכון של שוקולד, סוכר חום
# שוקולד – כמו שהסברתי קודם, הוא ללא שוקולד, הוא מתוק, מריר וחריף, יש כאלה שאוהבים
# את זה גם ככה, אז אתם צריכים להשתמש בכל התמרים יחד או להכניס את שאר החומרים
# להתקשות. את הקינוחים אתם יכולים גם להכין לבד, אבל גם את הקינוחים
# השוקולד, צריך להיות רך מאוד, בלי שוקולד, אבל הוא מתוק וטעים, אחרת השוקולד
# והשוקולד לא, אז אני מעדיף להשתמש בקרם קוקוס, או שקדים, רק זה לא. ואם
# אתם ממש אוהבים קקאו, אז את
#
# ----------------------------------------------------------------------------------------------------
